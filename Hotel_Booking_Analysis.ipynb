# %% [markdown]
# <a href="https://colab.research.google.com/github/Nargis45/Hotel-Booking-Analysis/blob/main/Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Hotel Booking Analysis**

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!**
#
# **This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.**
#
# **Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# # **Dataset Information**
#
#
# *   Number of instances: 119390
# *   Number of attributes: 32

# %% [markdown]
# # **Features information:**
#
# **The dataset contains features like:**
#
# * **hotel**: H1 = Resort Hotel, H2 = City Hotel
# * **is_canceled**: If the booking was cancelled(1) or not(0)
# * **lead_time**: Number of days that elasped between the entering date of the booking into the PMS and the arrival date
# * **arrival_date_year**: Year of arrival date
# * **arrival_date_month**: Month of arrival date
# * **arrival_date_week_number**: Weekday for arrival date
# * **arrival_date_day**: Day of arrival date
# * **stays_in_weekend_nights**: Number of weekend nights (sat or sun) the guest stayed or booked to stay at hotel
# * **stays_in_week_nights**: Number of week nights (sat or sun) the guest stayed or booked to stay at hotel
# * **adults**: Number of adults
# * **children**: Number of children
# * **babies**: Number of babies
# * **meal**: Kind of meal opted for
# * **country**: Country code
# * **market_segment**: Which segment the customer belongs to
# * **distribution_channel**: How the customer accessed the stay-corporate booking/direct/TA.TO
# * **is_repeated_guest**: Guest coming for first time or not
# * **previous_cancellations**: Was there a cancellation before
# * **previous_bookings**: Count of previous bookings
# * **reserved_room_type**: Type of room reserved
# * **assigned_room_type**: Type of room assigned
# * **booking_changes**: Count of changes made to booking
# * **deposit_type**: Deposit type
# * **agent**: Booking through agent
# * **days_in_waiting_list**: Number of days in waiting list
# * **customer_type**: Type of customer
# * **required_car_parking**: If car is required
# * **total_of_special_req**: Number of additional special requirements
# * **reservation_status**: Reservation of status
# * **reservation_status_date**: Date of specific status

# %% [markdown]
# ### **Goal:** **The main objective is to discover important factors that govern the bookings.**

# %% [markdown]
# # **Project Work flow**
# 1. **Importing Libraries**
#
# 2. **Loading the Dataset**
#
# 3. **Data Cleaning**
#
# 4. **Handling Outliers**
#
# 5. **Data Visualization**
#
# 6. **Conclusion**

# %% [markdown]
# # **1. Importing Libraries**

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # **2. Loading the Dataset**

# %% [markdown]
# **Mounting drive**

# %%
from google.colab import drive     
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **CSV File Location**

# %%
file_path='/content/drive/MyDrive/Colab Notebooks/Hotel Bookings.csv'

# %%
data=pd.read_csv(file_path)

# %%
# to display all columns
pd.set_option('display.max_columns', None)

# %%
# display first 5 rows of dataset
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %% [markdown]
# **Now, we have loaded the dataset. So, let's start with understanding the dataset.**

# %% [markdown]
# # **3. Data Cleaning**

# %%
#to see number of rows and columns
data.shape
# Out:
# (119390, 32)

# %%
# Finding the information regarding the null values and datatypes of all the columns in our dataset.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#checking for duplicacy in the dataset
data.duplicated().sum()
# Out:
# 31994

# %%
# plotting the duplicated data in the dataset 
plt.figure(figsize=(10,8))
sns.countplot(x=data.duplicated())

# %% [markdown]
# * **The dataset contain 31994 duplicate rows.**
# * **So we will drop the duplicate rows from our data.**

# %%
# dropping the duplicate rows
data= data.drop_duplicates()

# %%
# updated number of rows and columns after dropping the duplicates
data.shape
# Out:
# (87396, 32)

# %%
# Finding the count of null values in all the columns of our dataset.
data.isnull().sum().sort_values(ascending=False)
# Out:
# company                           82137
# agent                             12193
# country                             452
# children                              4
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# hotel                                 0
# previous_cancellations                0
# days_in_waiting_list                  0
# customer_type                         0
# adr                                   0
# required_car_parking_spaces           0
# total_of_special_requests             0
# reservation_status                    0
# previous_bookings_not_canceled        0
# is_repeated_guest                     0
# is_canceled                           0
# distribution_channel                  0
# market_segment                        0
# meal                                  0
# babies                                0
# ...

# %%
# plotting the null/missing data in the dataset
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.rcParams['figure.figsize'] = (20, 6)

# %% [markdown]
# **The dataset contains NaN values in few columns like:**
#
# * **company**
# * **agent**
# * **country**
# * **children**

# %% [markdown]
# ### **Replacing the null values**
# * **for company and agent fill the missing values with 0.**
# * **for country fill missing values with 'Others'.**
# * **AS the count of missing values in Children Column is only 4, so replace with 0 considering no children.**

# %%
# Filling/replacing null values with 0.
null_columns=['agent','children','company']
for col in null_columns:
  data[col].fillna(0,inplace=True)


# Replacing NA values with 'Others'
data['country'].fillna('Others',inplace=True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# * **No null values**

# %% [markdown]
# **Finding the rows where sum of of number of adlults ,children and babies is 0**

# %%
len(data[data['adults']+data['babies']+data['children']==0])
# Out:
# 166

# %% [markdown]
# **Dropping the 166 rows as no booking is made**

# %%
# droppping all those rows where sum of of adlults ,children and babies is 0. 
data.drop(data[data['adults']+data['babies']+data['children']==0].index,inplace=True)

# %%
data.shape
# Out:
# (87230, 32)

# %% [markdown]
# # **4. Handling Outliers**

# %%
#checking the outliers
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
 
((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# adr                                2508
# adults                            22733
# agent                                 0
# arrival_date_day_of_month             0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_year                     0
# assigned_room_type                    0
# babies                              914
# booking_changes                   15805
# children                           8364
# company                            5237
# country                               0
# customer_type                         0
# days_in_waiting_list                855
# deposit_type                          0
# distribution_channel                  0
# ...

# %% [markdown]
# * **The outliers need to be treated well.**
# * **I am replacing the outliers with the extreme values.**

# %%
# maximum number of car parking space is set to 3
data.loc[data.required_car_parking_spaces > 3,'required_car_parking_spaces'] = 3

# %%
# Updating the outliers
for i in ['lead_time','stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'booking_changes', 'days_in_waiting_list', 'adr', 'total_of_special_requests','previous_cancellations']:
  Q1 = data[i].quantile(0.25)
  Q3 = data[i].quantile(0.75)
  IQR = Q3 - Q1
 
  data[i]=np.where(data[i]<(Q1 - 1.5 * IQR),(Q1 - 1.5 * IQR),np.where(data[i]>(Q3 + 1.5 * IQR),(Q3 + 1.5 * IQR),data[i]))

# %%
#checking the outliers again
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
 
((data < (Q1 - 1.5 * IQR)) | (data > (Q3 + 1.5 * IQR))).sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# adr                                  0
# adults                               0
# agent                                0
# arrival_date_day_of_month            0
# arrival_date_month                   0
# arrival_date_week_number             0
# arrival_date_year                    0
# assigned_room_type                   0
# babies                               0
# booking_changes                      0
# children                             0
# company                           5237
# country                              0
# customer_type                        0
# days_in_waiting_list                 0
# deposit_type                         0
# distribution_channel                 0
# ...

# %% [markdown]
# * **Now, we don't have any outliers.**

# %% [markdown]
# ### **Data Manipulation**

# %%
# Adding 2 columns
data['total_people'] = data['adults'] + data['babies'] + data['children']   
data['total_stay'] = data['stays_in_weekend_nights'] + data['stays_in_week_nights']

# %%
data.shape
# Out:
# (87230, 34)

# %% [markdown]
# **Let's drop unimportant data**

# %%
data.drop(data[data['adults'] == 0].index, inplace = True)
data.drop(data[data['total_stay'] == 0].index, inplace = True)
data.drop(data[data['assigned_room_type'] == 0].index, inplace = True)

# %%
data.shape
# Out:
# (86639, 34)

# %% [markdown]
# # **5. Expolatory Data Analysis(EDA)**

# %% [markdown]
# ## **Finding the preferred hotel**

# %%
data['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.2f%%', figsize=(5,5),fontsize=12)   
plt.title('Most Preffered Hotel')
# Out:
# Text(0.5, 1.0, 'Most Preffered Hotel')

# %% [markdown]
# * **city hotels have maximum bookings**

# %% [markdown]
# ## **Checking cancellation %age**

# %%
data['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.2f%%', figsize=(5,5),fontsize=12)
plt.title("Cancellation %age")
# Out:
# Text(0.5, 1.0, 'Cancellation %age')

# %% [markdown]
# * **0: not canceled**
# * **1: canceled**
# * **Hence, 27.68% of bookings were canceled.**

# %% [markdown]
# ## **Calculating %age of repeated and non-repeated guests**

# %%
data['is_repeated_guest'].value_counts().plot.pie(autopct='%1.2f%%',figsize=(6,6),fontsize=12)
plt.title(" Percentgae of repeated guests")
# Out:
# Text(0.5, 1.0, ' Percentgae of repeated guests')

# %% [markdown]
# * **0: not repeated guests**
# * **1: repeated guests**
# * **Hence, 3.63% of guests have visited before.**
#
# **As visited guests %age is really low, so hotel should come up with exciting offers and deals.**

# %% [markdown]
# ## **%age of guests using parking space**

# %%
data['required_car_parking_spaces'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(5,5),fontsize=12,labels=None)
labels=data['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(labels=labels)

# %% [markdown]
# * **91.6 % guests did not required the parking space.**
# * **Only 8.3 % guests required 1 parking space.**

# %% [markdown]
# ## **Types of meal preferred by customers**

# %%
plt.figure(figsize=(8,8))
sns.countplot(x=data['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# **Types of meal in hotels:**
#
# * **BB - (Bed and Breakfast)**
# * **HB- (Half Board)**
# * **FB- (Full Board)**
# * **SC- (Self Catering)**
#
# **Observation**
# * **So the most preferred meal type by the guests is BB( Bed and Breakfast)**
# * **HB- (Half Board) and SC- (Self Catering) are equally preferred.**

# %% [markdown]
# ### **Top 10 countries with maximum number of guests**

# %%
country_df=data['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# * **PRT: Portugal**
# * **GBR: United Kingdom**
# * **FRA: France**
# * **ESP: Spain**
# * **DEU: Germany**
# * **ITA: Italy**
# * **IRL: Ireland**
# * **BEL: Belgium**
# * **BRA: Brazil**
# * **NLD: Netherlands**
#
# **Most of the guests are from Portugal followed by United Kingdom and France.**

# %% [markdown]
# ## **Number of bookings each month**

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=data.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')
bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4638
# 3            February    6030
# 7               March    7440
# 0               April    7870
# 8                 May    8296
# 6                June    7721
# 5                July    9988
# 1              August   11194
# 11          September    6659
# 10            October    6842
# 9            November    4916
# 2            December    5045

# %%
# set plot size
plt.figure(figsize=(16,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# * **July and August have the maximum number of Bookings.**

# %% [markdown]
# ### **Plotting the months against hotel type**

# %%
plt.figure(figsize=(12,4))
sns.countplot(x='arrival_date_month', hue = 'hotel', data= data)
plt.title('Months of Arrival')
plt.show()

# %% [markdown]
# * **Most people prefer city hotel.**

# %% [markdown]
# ### **Year with maximum number of bookings**

# %%
plt.figure(figsize=(6,6))
data.arrival_date_year.value_counts().plot(kind="bar")                                    
plt.show()

# %% [markdown]
# * **2016 has maximum number of bookings**

# %%
# This graph shows the booking made in each month for different hotel types.
sns.set(rc={'figure.figsize':(8,8)})
ax = sns.countplot(x = 'arrival_date_year',hue='hotel', data=data)
ax.set_title('Bookings Made in each Year',fontsize = 14, fontweight='bold')
ax.set_xlabel('Year',fontsize = 12)
ax.set_ylabel('Reservation Count',fontsize = 12)
# Out:
# Text(0, 0.5, 'Reservation Count')

# %% [markdown]
# * **In most of the year City hotel bookings is higher than Resort hotel bookings.**

# %% [markdown]
# ## **Bookings made through different Distribution channel**

# %%
sns.set(rc={'figure.figsize':(8,8)})
ax = sns.countplot(x='distribution_channel', data=data)
ax.set_title('Bookings made through different Distribution channel',fontsize = 14, fontweight='bold')
ax.set_xlabel('Distribution Channel',fontsize = 12)
ax.set_ylabel('No. of bookings',fontsize = 12)
# Out:
# Text(0, 0.5, 'No. of bookings')

# %% [markdown]
# * **TA/TO: Travel agents/Tour operators**
# * **TA/TO made maximum number of bookings**

# %% [markdown]
# ##**Deposit type in different hotel type.**

# %%
sns.set(rc={'figure.figsize':(10,8)})
graph = sns.countplot(hue=data['hotel'],x=data['deposit_type'])
graph.set_title('Deposit criteria in different hotel type',fontsize = 16, fontweight='bold')
graph.set_xlabel('Type of deposits',fontsize = 14)
graph.set_ylabel('Reservation Count',fontsize = 14)
plt.legend(loc='upper right')

# %% [markdown]
# * **No deposit criteria is followed by both type of hotels.**

# %% [markdown]
# ## **Number of special request recieved by hotels.**

# %%
sns.set(rc={'figure.figsize':(8,8)})
graph = sns.countplot(data["total_of_special_requests"], hue=data["hotel"], data=data)
graph.set_title('Special request recieved by hotel',fontsize = 12, fontweight='bold')
graph.set_xlabel('No. of Special Requests',fontsize = 12)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 0, 'No. of Special Requests')

# %% [markdown]
# * **City hotels receives more special requests than Resort hotels.**

# %% [markdown]
# ## **Plotting status of reservations made by people.**

# %%
data['reservation_status'].value_counts().plot.pie(autopct='%.0f%%', figsize=(6,6),fontsize=12)
plt.legend(labels=data['reservation_status'].value_counts().index)
plt.title('Reservation status',fontsize = 12, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Reservation status')

# %% [markdown]
# * **Out of total no of reservations 63% actually show up, 36% got canceled, and only 1% reservation got No show.**

# %% [markdown]
# ## **Number of days spend in hotels.**

# %%
# This graph shows No. of total stays in each hotel type.
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.countplot(x ='total_stay',hue='hotel', data=data)
ax.set_title('Optimal stay in each hotel type',fontsize = 14, fontweight='bold')
ax.set_xlabel('No. of days',fontsize = 12)
ax.set_ylabel('Reservation Count',fontsize = 12)
plt.legend(loc='upper right')

# %% [markdown]
# * **For days<=5 people prefer to stay in city hotel.**
# * **For days>5 people prefer to stay in resort hotel.**

# %% [markdown]
# ## **Average daily price(ADR) of hotels.**

# %%
hotel_price = data.groupby('hotel')['adr'].mean().reset_index()
sns.set(rc={'figure.figsize':(8,8)})
graph = sns.barplot(x='hotel',y='adr', data=hotel_price)
graph.set_title('Hotel price distribution',fontsize = 14, fontweight='bold')
graph.set_xlabel('Hotel Type',fontsize = 12)
graph.set_ylabel('Avg Daily Price',fontsize = 12)
# Out:
# Text(0, 0.5, 'Avg Daily Price')

# %% [markdown]
# * **ADR of city hotel is higher than resort hotel.**

# %% [markdown]
# ## **Average lead time of hotels.**

# %%
avg_lead_time = data.groupby('hotel')['lead_time'].mean().reset_index()

#set plot size
plt.figure(figsize=(8,8))

# plot the bar plot
sns.barplot(x=avg_lead_time['hotel'],y=avg_lead_time['lead_time'])
# set lables
plt.xlabel('Hotel type')
plt.ylabel('Average Lead time')
plt.title("Average Lead Time for each Hotel type")
# Out:
# Text(0.5, 1.0, 'Average Lead Time for each Hotel type')

# %% [markdown]
# * **Average lead time of resort hotel is higher than city hotel, i.e, people prefer to stay in resort hotel for maximum number of days.**

# %% [markdown]
# ## **ADR of hotels across distribution channel.**

# %%
distribution_channel_df=data.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# set plot size
plt.figure(figsize=(10,8))
sns.barplot(x='distribution_channel', y='adr', data=distribution_channel_df, hue='hotel')
plt.title('ADR across Distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across Distribution channel')

# %% [markdown]
# # **6. Conclusion:**
#
# **1. City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.**
#
# **2. 27.5 % bookings were got cancelled out of all the bookings.**
#
# **3. Only 3.9 % people were revisited the hotels. Rest 96.1 % were new guests. So hotel needs should use different offers and ways to increase the %age of revisited guests.**
#
# **4. Most of the customers (91.6%) do not require car parking spaces.**
#
# **5. 79.1 % bookings were made through TA/TO (travel agents/Tour operators).**
#
# **6. BB( Bed & Breakfast) is the most preferred type of meal by the guests.**
#
# **7. Maximum number of guests were from Portugal, i.e. more than 25000 guests.**
#
# **8. Most of the bookings for City hotels and Resort hotel were happened in 2016.**
#
# **9. Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.**
#
# **10. Average lead time for resort hotel is high.**
#
# **11. If guests have to stay more than 5 days they prefer resort hotel.**
